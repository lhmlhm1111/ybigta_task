# %% [markdown]
# # Flower Recognition CNN Keras

# %% [markdown]
# <a id="content1"></a>
# ## 1 ) Importing Various Modules.

# %%
# Ignore  the warnings
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# data visualisation and manipulation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
 
#configure
# sets matplotlib to inline and displays graphs below the corressponding cell.
# %matplotlib inline  
style.use('fivethirtyeight')
sns.set(style='whitegrid',color_codes=True)

#model selection
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix,roc_curve,roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder

#preprocess.
from keras.preprocessing.image import ImageDataGenerator

#dl libraraies
from keras import backend as K
#from keras.models import Sequential
#from keras.layers import Dense
from tensorflow.keras.optimizers import Adam,SGD,Adagrad,Adadelta,RMSprop
from tensorflow.keras.utils import to_categorical

# specifically for cnn
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dropout, Flatten,Activation, Dense
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization

import tensorflow as tf
import random as rn

# specifically for manipulating zipped images and getting numpy arrays of pixel values of images.
import cv2                  
import numpy as np  
from tqdm import tqdm
import os                   
from random import shuffle  
from zipfile import ZipFile
from PIL import Image

# %% [markdown]
# <a id="content2"></a>
# ## 2 ) Preparing the Data

# %% [markdown]
# ## 2.1) Making the functions to get the training and validation set from the Images

# %%
X=[]
Z=[]
IMG_SIZE=150
FLOWER_DAISY_DIR='./flowers/daisy'
FLOWER_SUNFLOWER_DIR='./flowers/sunflower'
FLOWER_TULIP_DIR='./flowers/tulip'
FLOWER_DANDI_DIR='./flowers/dandelion'
FLOWER_ROSE_DIR='./flowers/rose'

# %%
def assign_label(img,flower_type):
    return flower_type

# %%
def make_train_data(flower_type,DIR):
    for img in tqdm(os.listdir(DIR)):
        label=assign_label(img,flower_type)
        path = os.path.join(DIR,img)
        img = cv2.imread(path,cv2.IMREAD_COLOR)
        img = cv2.resize(img, (IMG_SIZE,IMG_SIZE))
        
        X.append(np.array(img))
        Z.append(str(label))

# %%
make_train_data('Daisy',FLOWER_DAISY_DIR)
print(len(X))
# Out:
# 100%|██████████| 764/764 [00:01<00:00, 743.23it/s]
# 764

# %%
make_train_data('Sunflower',FLOWER_SUNFLOWER_DIR)
print(len(X))
# Out:
# 100%|██████████| 733/733 [00:01<00:00, 606.33it/s]
# 1497

# %%
make_train_data('Tulip',FLOWER_TULIP_DIR)
print(len(X))
# Out:
# 100%|██████████| 984/984 [00:01<00:00, 694.26it/s]
# 2481

# %%
make_train_data('Dandelion',FLOWER_DANDI_DIR)
print(len(X))
# Out:
# 100%|██████████| 1052/1052 [00:01<00:00, 732.20it/s]
# 3533

# %%
make_train_data('Rose',FLOWER_ROSE_DIR)
print(len(X))
# Out:
# 100%|██████████| 784/784 [00:01<00:00, 759.80it/s]
# 4317

# %% [markdown]
# ## 2.2 ) Visualizing some Random Images

# %%
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=rn.randint(0,len(Z))
        ax[i,j].imshow(X[l])
        ax[i,j].set_title('Flower: '+Z[l])
        
plt.tight_layout()

# %% [markdown]
# ## 2.3 ) Label Encoding the Y array (i.e. Daisy->0, Rose->1 etc...) & then One Hot Encoding

# %%
le=LabelEncoder()
Y=le.fit_transform(Z)
Y=to_categorical(Y,5)
X=np.array(X)
X=X/255

# %% [markdown]
# ## 2.4 ) Splitting into Training and Validation Sets

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.25,random_state=42)

# %% [markdown]
# ## 2.5 ) Setting the Random Seeds

# %%
np.random.seed(42)
rn.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# <a id="content3"></a>
# ## 3 ) Modelling

# %% [markdown]
# ## 3.1 ) Building the ConvNet Model

# %%
# # modelling starts using a CNN.
#물을표를  채워주세요.!
#Hint Padding은 전부 대중적인 즉 stride가 1이라면 input과 output 사이즈를 같게 만들어주는 패딩
#Hint 커널사이즈도 대중적인 커널사이즈
#은닉충에 주로쓰는 Activation
model = Sequential()
model.add(Conv2D(filters = 32, kernel_size = (3,3), padding = 'same',activation ='relu', input_shape = (150,150,3)))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Conv2D(filters = 64, kernel_size = (3,3), padding = 'same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))


model.add(Conv2D(filters =96, kernel_size = (3,3), padding = 'same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Conv2D(filters = 96, kernel_size = (3,3),padding = 'same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dense(5, activation = "softmax")) #우리가 몇개로 분류하나요?, 다중분류에 맞는 activation

# %% [markdown]
# ## 3.2 ) Using a LR Annealer

# %%
batch_size=128
epochs=50

from keras.callbacks import ReduceLROnPlateau
red_lr= ReduceLROnPlateau(monitor='val_acc',patience=3,verbose=1,factor=0.1)

# %% [markdown]
# ## 3.3 ) Data Augmentation to prevent Overfitting

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(x_train)

# %% [markdown]
# ## 3.4 ) Compiling the Keras Model & Summary

# %%
model.compile(optimizer=Adam(lr=0.001),loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 96)        55392
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 96)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 96)        83040
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 96)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 7776)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               3981824
# _________________________________________________________________
# activation (Activation)      (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 2565
# =================================================================
# Total params: 4,142,213
# Trainable params: 4,142,213
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 3.5 ) Fitting on the Training set and making predcitons on the Validation set

# %%
History = model.fit_generator(datagen.flow(x_train,y_train, batch_size=batch_size),
                              epochs = epochs, validation_data = (x_test,y_test),
                              verbose = 1, steps_per_epoch=x_train.shape[0] // batch_size)

# model.fit(x_train,y_train,epochs=epochs,batch_size=batch_size,validation_data = (x_test,y_test))
# Out:
# Epoch 1/50
# 25/25 [==============================] - 23s 873ms/step - loss: 1.4984 - accuracy: 0.3084 - val_loss: 1.2591 - val_accuracy: 0.4667
# Epoch 2/50
# 25/25 [==============================] - 21s 833ms/step - loss: 1.2254 - accuracy: 0.4828 - val_loss: 1.0082 - val_accuracy: 0.6019
# Epoch 3/50
# 25/25 [==============================] - 21s 836ms/step - loss: 1.0538 - accuracy: 0.5803 - val_loss: 1.0219 - val_accuracy: 0.5917
# Epoch 4/50
# 25/25 [==============================] - 21s 840ms/step - loss: 0.9665 - accuracy: 0.6311 - val_loss: 0.9348 - val_accuracy: 0.6398
# Epoch 5/50
# 25/25 [==============================] - 22s 847ms/step - loss: 0.9628 - accuracy: 0.6310 - val_loss: 0.9011 - val_accuracy: 0.6750
# Epoch 6/50
# 25/25 [==============================] - 21s 868ms/step - loss: 0.8844 - accuracy: 0.6595 - val_loss: 0.9520 - val_accuracy: 0.6324
# Epoch 7/50
# 25/25 [==============================] - 22s 848ms/step - loss: 0.8310 - accuracy: 0.6832 - val_loss: 0.7908 - val_accuracy: 0.7019
# Epoch 8/50
# 25/25 [==============================] - 22s 844ms/step - loss: 0.8117 - accuracy: 0.6877 - val_loss: 0.8041 - val_accuracy: 0.7000
# Epoch 9/50
# 25/25 [==============================] - 21s 843ms/step - loss: 0.8114 - accuracy: 0.6970 - val_loss: 0.8102 - val_accuracy: 0.7065
# Epoch 10/50
# 25/25 [==============================] - 22s 851ms/step - loss: 0.7499 - accuracy: 0.7093 - val_loss: 0.7869 - val_accuracy: 0.7148
# Epoch 11/50
# 25/25 [==============================] - 22s 863ms/step - loss: 0.7842 - accuracy: 0.7019 - val_loss: 0.7710 - val_accuracy: 0.7194
# Epoch 12/50
# 25/25 [==============================] - 22s 857ms/step - loss: 0.6932 - accuracy: 0.7395 - val_loss: 0.7711 - val_accuracy: 0.7139
# Epoch 13/50
# 25/25 [==============================] - 22s 853ms/step - loss: 0.7097 - accuracy: 0.7261 - val_loss: 0.7263 - val_accuracy: 0.7370
# Epoch 14/50
# 25/25 [==============================] - 22s 862ms/step - loss: 0.6892 - accuracy: 0.7293 - val_loss: 0.7534 - val_accuracy: 0.7370
# Epoch 15/50
# 25/25 [==============================] - 22s 855ms/step - loss: 0.6426 - accuracy: 0.7563 - val_loss: 0.7033 - val_accuracy: 0.7509
# Epoch 16/50
# 25/25 [==============================] - 21s 837ms/step - loss: 0.6689 - accuracy: 0.7434 - val_loss: 0.6625 - val_accuracy: 0.7639
# Epoch 17/50
# 25/25 [==============================] - 22s 846ms/step - loss: 0.5729 - accuracy: 0.7890 - val_loss: 0.6718 - val_accuracy: 0.7593
# Epoch 18/50
# 25/25 [==============================] - 22s 853ms/step - loss: 0.6023 - accuracy: 0.7718 - val_loss: 0.6720 - val_accuracy: 0.7704
# Epoch 19/50
# 25/25 [==============================] - 21s 836ms/step - loss: 0.5878 - accuracy: 0.7764 - val_loss: 0.6720 - val_accuracy: 0.7444
# Epoch 20/50
# 25/25 [==============================] - 22s 858ms/step - loss: 0.5720 - accuracy: 0.7867 - val_loss: 0.6685 - val_accuracy: 0.7704
# Epoch 21/50
# 25/25 [==============================] - 22s 847ms/step - loss: 0.5693 - accuracy: 0.7905 - val_loss: 0.6426 - val_accuracy: 0.7778
# Epoch 22/50
# 25/25 [==============================] - 22s 851ms/step - loss: 0.5210 - accuracy: 0.8068 - val_loss: 0.6991 - val_accuracy: 0.7722
# Epoch 23/50
# 25/25 [==============================] - 22s 850ms/step - loss: 0.5104 - accuracy: 0.8094 - val_loss: 0.7227 - val_accuracy: 0.7565
# Epoch 24/50
# 25/25 [==============================] - 22s 868ms/step - loss: 0.5117 - accuracy: 0.8101 - val_loss: 0.6356 - val_accuracy: 0.7880
# Epoch 25/50
# 25/25 [==============================] - 22s 854ms/step - loss: 0.4662 - accuracy: 0.8298 - val_loss: 0.6612 - val_accuracy: 0.7667
# Epoch 26/50
# 25/25 [==============================] - 22s 849ms/step - loss: 0.4629 - accuracy: 0.8341 - val_loss: 0.6732 - val_accuracy: 0.7796
# Epoch 27/50
# 25/25 [==============================] - 21s 868ms/step - loss: 0.4619 - accuracy: 0.8202 - val_loss: 0.6163 - val_accuracy: 0.7852
# Epoch 28/50
# 25/25 [==============================] - 22s 854ms/step - loss: 0.4339 - accuracy: 0.8401 - val_loss: 0.7135 - val_accuracy: 0.7667
# Epoch 29/50
# 25/25 [==============================] - 22s 853ms/step - loss: 0.5035 - accuracy: 0.8081 - val_loss: 0.6472 - val_accuracy: 0.7796
# Epoch 30/50
# 25/25 [==============================] - 22s 854ms/step - loss: 0.4387 - accuracy: 0.8355 - val_loss: 0.6207 - val_accuracy: 0.7824
# Epoch 31/50
# 25/25 [==============================] - 22s 864ms/step - loss: 0.4640 - accuracy: 0.8301 - val_loss: 0.6258 - val_accuracy: 0.7917
# Epoch 32/50
# 25/25 [==============================] - 22s 856ms/step - loss: 0.4094 - accuracy: 0.8493 - val_loss: 0.6275 - val_accuracy: 0.7972
# Epoch 33/50
# 25/25 [==============================] - 22s 864ms/step - loss: 0.4066 - accuracy: 0.8410 - val_loss: 0.6496 - val_accuracy: 0.7880
# Epoch 34/50
# 25/25 [==============================] - 22s 871ms/step - loss: 0.3994 - accuracy: 0.8518 - val_loss: 0.6420 - val_accuracy: 0.7954
# Epoch 35/50
# 25/25 [==============================] - 22s 847ms/step - loss: 0.3560 - accuracy: 0.8693 - val_loss: 0.6727 - val_accuracy: 0.7963
# Epoch 36/50
# 25/25 [==============================] - 22s 844ms/step - loss: 0.4046 - accuracy: 0.8507 - val_loss: 0.6258 - val_accuracy: 0.7926
# Epoch 37/50
# 25/25 [==============================] - 22s 863ms/step - loss: 0.3484 - accuracy: 0.8656 - val_loss: 0.6146 - val_accuracy: 0.7917
# Epoch 38/50
# 25/25 [==============================] - 22s 868ms/step - loss: 0.3786 - accuracy: 0.8594 - val_loss: 0.6492 - val_accuracy: 0.7907
# Epoch 39/50
# 25/25 [==============================] - 22s 868ms/step - loss: 0.3681 - accuracy: 0.8660 - val_loss: 0.7317 - val_accuracy: 0.7741
# Epoch 40/50
# 25/25 [==============================] - 22s 853ms/step - loss: 0.3553 - accuracy: 0.8622 - val_loss: 0.6189 - val_accuracy: 0.7907
# Epoch 41/50
# 25/25 [==============================] - 22s 855ms/step - loss: 0.3408 - accuracy: 0.8817 - val_loss: 0.6292 - val_accuracy: 0.7926
# Epoch 42/50
# 25/25 [==============================] - 22s 864ms/step - loss: 0.3190 - accuracy: 0.8824 - val_loss: 0.6561 - val_accuracy: 0.7926
# Epoch 43/50
# 25/25 [==============================] - 22s 865ms/step - loss: 0.3095 - accuracy: 0.8905 - val_loss: 0.6525 - val_accuracy: 0.7880
# Epoch 44/50
# 25/25 [==============================] - 22s 866ms/step - loss: 0.3039 - accuracy: 0.8895 - val_loss: 0.6890 - val_accuracy: 0.7963
# Epoch 45/50
# 25/25 [==============================] - 22s 846ms/step - loss: 0.2681 - accuracy: 0.8940 - val_loss: 0.7378 - val_accuracy: 0.7926
# Epoch 46/50
# 25/25 [==============================] - 22s 846ms/step - loss: 0.2727 - accuracy: 0.9002 - val_loss: 0.7215 - val_accuracy: 0.8000
# Epoch 47/50
# 25/25 [==============================] - 22s 876ms/step - loss: 0.2606 - accuracy: 0.8999 - val_loss: 0.6851 - val_accuracy: 0.8056
# Epoch 48/50
# 25/25 [==============================] - 22s 858ms/step - loss: 0.2414 - accuracy: 0.9082 - val_loss: 0.6690 - val_accuracy: 0.7907
# Epoch 49/50
# 25/25 [==============================] - 22s 858ms/step - loss: 0.2314 - accuracy: 0.9121 - val_loss: 0.7503 - val_accuracy: 0.7917
# Epoch 50/50
# 25/25 [==============================] - 22s 862ms/step - loss: 0.2540 - accuracy: 0.9050 - val_loss: 0.6682 - val_accuracy: 0.8000

# %% [markdown]
# <a id="content4"></a>
# ## 4 ) Evaluating the Model Performance

# %%
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %%
plt.plot(History.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %% [markdown]
# #### CORRECTLY CLASSIFIED FLOWER IMAGES

# %% [markdown]
# #  THE END.
